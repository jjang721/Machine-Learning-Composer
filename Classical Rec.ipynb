# %% [markdown]
# # Classical Rec System

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
music = pd.read_csv('classical_composers.csv', on_bad_lines='skip' , encoding='latin-1')

# %%
music.head(2)
# Out:
#                Composer   Nationality     Born    Died      Biggest Piece  \
# 0                   NaN            NaN     NaN     NaN                NaN
# 1  Ludwig van Beethoven      German     1770.0  1791.0  Symphony No. 9
#
#    Duration of Biggest Piece(mins)
# 0                              NaN
# 1                             65.0

# %%
music.shape
# Out:
# (101, 6)

# %%
music.columns
# Out:
# Index(['Composer', '  Nationality ', ' Born', 'Died', 'Biggest Piece',
#        'Duration of Biggest Piece(mins)'],
#       dtype='object')

# %%
music = music[['Composer', '  Nationality ', ' Born', 'Died', 'Biggest Piece',
       'Duration of Biggest Piece(mins)']]

# %%
music.head(2)
# Out:
#                Composer   Nationality     Born    Died      Biggest Piece  \
# 0                   NaN            NaN     NaN     NaN                NaN
# 1  Ludwig van Beethoven      German     1770.0  1791.0  Symphony No. 9
#
#    Duration of Biggest Piece(mins)
# 0                              NaN
# 1                             65.0

# %%
music.rename(columns={
    'Nationality': 'nationality',
}, inplace = True)

# %%
music.head()
# Out:
#                    Composer   Nationality     Born    Died  \
# 0                       NaN            NaN     NaN     NaN
# 1      Ludwig van Beethoven      German     1770.0  1791.0
# 2  Wolfgang Amadeus Mozart        Austrian  1756.0  1791.0
# 3    Johann Sebastian Bach       German     1685.0  1750.0
# 4            Richard Wagner      German     1813.0  1883.0
#
#              Biggest Piece  Duration of Biggest Piece(mins)
# 0                      NaN                              NaN
# 1        Symphony No. 9                                65.0
# 2           Symphony No.41                             33.0
# 3          Mass in B minor                            125.0
# 4  Der Ring des Nibelungen                              NaN

# %%
music.rename(columns={
    'Nationality': 'nationality'
}, inplace = True)

# %%
music.head()
# Out:
#                    Composer   Nationality     Born    Died  \
# 0                       NaN            NaN     NaN     NaN
# 1      Ludwig van Beethoven      German     1770.0  1791.0
# 2  Wolfgang Amadeus Mozart        Austrian  1756.0  1791.0
# 3    Johann Sebastian Bach       German     1685.0  1750.0
# 4            Richard Wagner      German     1813.0  1883.0
#
#              Biggest Piece  Duration of Biggest Piece(mins)
# 0                      NaN                              NaN
# 1        Symphony No. 9                                65.0
# 2           Symphony No.41                             33.0
# 3          Mass in B minor                            125.0
# 4  Der Ring des Nibelungen                              NaN

# %%
music.head(8)
# Out:
#                    Composer   Nationality     Born    Died  \
# 0                       NaN            NaN     NaN     NaN
# 1      Ludwig van Beethoven      German     1770.0  1791.0
# 2  Wolfgang Amadeus Mozart        Austrian  1756.0  1791.0
# 3    Johann Sebastian Bach       German     1685.0  1750.0
# 4            Richard Wagner      German     1813.0  1883.0
# 5             Joseph Haydn        Austrian  1732.0  1809.0
# 6           Johannes Brahms      German     1833.0  1897.0
# 7           Franz Schubert        Austrian  1797.0  1828.0
#
#              Biggest Piece  Duration of Biggest Piece(mins)
# 0                      NaN                              NaN
# 1        Symphony No. 9                                65.0
# 2           Symphony No.41                             33.0
# 3          Mass in B minor                            125.0
# 4  Der Ring des Nibelungen                              NaN
# 5          Symphony No. 45                             25.0
# ...

# %%
music['Nationality'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nationality'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 music['Nationality'].value_counts()
#
# ...

# %%
music['nationality'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nationality'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 music['nationality'].value_counts()
#
# ...

# %%
music.rename(columns={
    "Nationality": "nationality",
    "Born": "birth_year"}, inplace = True)

# %%
print(music)
# Out:
#                      Composer   Nationality     Born    Died  \
# 0                         NaN            NaN     NaN     NaN
# 1        Ludwig van Beethoven      German     1770.0  1791.0
# 2    Wolfgang Amadeus Mozart        Austrian  1756.0  1791.0
# 3      Johann Sebastian Bach       German     1685.0  1750.0
# 4              Richard Wagner      German     1813.0  1883.0
# ..                        ...            ...     ...     ...
# 96            Manuel de Falla        Spanish  1876.0  1946.0
# 97       Hildegard von Bingen      German     1098.0  1179.0
# 98             Mikhail Glinka        Russian  1804.0  1857.0
# 99         Alexander Glazunov        Russian  1865.0  1936.0
# 100        Don Carlo Gesualdo        Italian  1566.0  1613.0
#
#                                          Biggest Piece  \
# 0                                                  NaN
# 1                                    Symphony No. 9
# 2                                       Symphony No.41
# ...

# %%
music.rename(columns={
    '  Nationality ': "nationality",
    ' Born': "birth_year"}, inplace = True)

# %%
music.head()
# Out:
#                    Composer nationality  birth_year    Died  \
# 0                       NaN         NaN         NaN     NaN
# 1      Ludwig van Beethoven   German         1770.0  1791.0
# 2  Wolfgang Amadeus Mozart     Austrian      1756.0  1791.0
# 3    Johann Sebastian Bach    German         1685.0  1750.0
# 4            Richard Wagner   German         1813.0  1883.0
#
#              Biggest Piece  Duration of Biggest Piece(mins)
# 0                      NaN                              NaN
# 1        Symphony No. 9                                65.0
# 2           Symphony No.41                             33.0
# 3          Mass in B minor                            125.0
# 4  Der Ring des Nibelungen                              NaN

# %%
music['nationality'].value_counts()
# Out:
# nationality
# German            17
# French            17
# Italian           15
# Russian           11
# English           10
# Austrian          10
# American           5
# Czech              3
# Franco-Flemish     2
# Spanish            2
# Hungarian          2
# Flemish            1
# Norweigen          1
# Belgian            1
# Polish             1
# Danish             1
# Finnish            1
# Name: count, dtype: int64

# %%
x = music['nationality'].value_counts() > 10

# %%
x
# Out:
# nationality
# German             True
# French             True
# Italian            True
# Russian            True
# English           False
# Austrian          False
# American          False
# Czech             False
# Franco-Flemish    False
# Spanish           False
# Hungarian         False
# Flemish           False
# Norweigen         False
# Belgian           False
# Polish            False
# Danish            False
# Finnish           False
# Name: count, dtype: bool

# %%
x[x].shape
# Out:
# (4,)

# %%
y = x[x].index

# %%
y
# Out:
# Index(['German   ', 'French', 'Italian', 'Russian'], dtype='object', name='nationality')

# %%
music = music[music['nationality'].isin(y)]

# %%
music.head()
# Out:
#                     Composer nationality  birth_year    Died  \
# 1       Ludwig van Beethoven   German         1770.0  1791.0
# 3     Johann Sebastian Bach    German         1685.0  1750.0
# 4             Richard Wagner   German         1813.0  1883.0
# 6            Johannes Brahms   German         1833.0  1897.0
# 8  Peter Ilyich Tchaikovsky      Russian      1840.0  1893.0
#
#              Biggest Piece  Duration of Biggest Piece(mins)
# 1        Symphony No. 9                                65.0
# 3          Mass in B minor                            125.0
# 4  Der Ring des Nibelungen                              NaN
# 6         Symphony No. 4                               40.0
# 8           Symphony No. 6                             75.0

# %%
music.shape
# Out:
# (60, 6)

# %%
books.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 books.head()
#
# NameError: name 'books' is not defined

# %%
music.head()
# Out:
#                     Composer nationality  birth_year    Died  \
# 1       Ludwig van Beethoven   German         1770.0  1791.0
# 3     Johann Sebastian Bach    German         1685.0  1750.0
# 4             Richard Wagner   German         1813.0  1883.0
# 6            Johannes Brahms   German         1833.0  1897.0
# 8  Peter Ilyich Tchaikovsky      Russian      1840.0  1893.0
#
#              Biggest Piece  Duration of Biggest Piece(mins)
# 1        Symphony No. 9                                65.0
# 3          Mass in B minor                            125.0
# 4  Der Ring des Nibelungen                              NaN
# 6         Symphony No. 4                               40.0
# 8           Symphony No. 6                             75.0

# %%
classical.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 classical.head()
#
# NameError: name 'classical' is not defined

# %%
music.head(2)
# Out:
#                  Composer nationality  birth_year    Died      Biggest Piece  \
# 1    Ludwig van Beethoven   German         1770.0  1791.0  Symphony No. 9
# 3  Johann Sebastian Bach    German         1685.0  1750.0    Mass in B minor
#
#    Duration of Biggest Piece(mins)
# 1                             65.0
# 3                            125.0

# %%
music.rename(columns={
    'Composer': "composer",
    '  Nationality ': "nationality",
    ' Born': "birth_year", 'Died':"died", "Biggest Piece": "biggest_piece", "Duration of Biggest Piece(mins)": "duration_of_piece"}, inplace = True)

# %%
music.head()
# Out:
#                     composer nationality  birth_year    died  \
# 1       Ludwig van Beethoven   German         1770.0  1791.0
# 3     Johann Sebastian Bach    German         1685.0  1750.0
# 4             Richard Wagner   German         1813.0  1883.0
# 6            Johannes Brahms   German         1833.0  1897.0
# 8  Peter Ilyich Tchaikovsky      Russian      1840.0  1893.0
#
#              biggest_piece  duration_of_piece
# 1        Symphony No. 9                  65.0
# 3          Mass in B minor              125.0
# 4  Der Ring des Nibelungen                NaN
# 6         Symphony No. 4                 40.0
# 8           Symphony No. 6               75.0

# %%
music = music.pivot_table(columns= 'nationality', index= 'composer', values = 'duration_of_piece')

# %%
music
# Out:
# nationality                        French  German     Italian  Russian
# composer
#  Maurice Ravel                       15.0        NaN      NaN      NaN
# Alexander Borodin                     NaN        NaN      NaN     11.0
# Alexander Glazunov                    NaN        NaN      NaN     35.0
# Alexander Nikolayevich Scriabin       NaN        NaN      NaN     20.0
# Antonio Vivaldi                       NaN        NaN     40.0      NaN
# Camille Saint-Saens                  25.0        NaN      NaN      NaN
# Claude Debussy                       10.0        NaN      NaN      NaN
# Claudio Monteverdi                    NaN        NaN    135.0      NaN
# Darius Milhaud                       10.0        NaN      NaN      NaN
# Dmitri Shostakovich                   NaN        NaN      NaN     50.0
# Erik Satie                            7.0        NaN      NaN      NaN
# Felix Mendelssohn                     NaN       28.0      NaN      NaN
# ...

# %%
music.shape
# Out:
# (32, 4)

# %%
music.fillna(0, inplace=True)

# %%
music
# Out:
# nationality                        French  German     Italian  Russian
# composer
#  Maurice Ravel                       15.0        0.0      0.0      0.0
# Alexander Borodin                     0.0        0.0      0.0     11.0
# Alexander Glazunov                    0.0        0.0      0.0     35.0
# Alexander Nikolayevich Scriabin       0.0        0.0      0.0     20.0
# Antonio Vivaldi                       0.0        0.0     40.0      0.0
# Camille Saint-Saens                  25.0        0.0      0.0      0.0
# Claude Debussy                       10.0        0.0      0.0      0.0
# Claudio Monteverdi                    0.0        0.0    135.0      0.0
# Darius Milhaud                       10.0        0.0      0.0      0.0
# Dmitri Shostakovich                   0.0        0.0      0.0     50.0
# Erik Satie                            7.0        0.0      0.0      0.0
# Felix Mendelssohn                     0.0       28.0      0.0      0.0
# ...

# %%
from scipy.sparse import csr_matrix

# %%
music_sparse = csr_matrix(music)

# %%
music_sparse
# Out:
# <32x4 sparse matrix of type '<class 'numpy.float64'>'
# 	with 32 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(music_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
music_array = music.values
filtered_music = music_array[:, ~np.all(np.isnan(music_array), axis=0)]

input_data = music.iloc[18].values.reshape(1, -1)  # Select a single row
if input_data.shape[1] != filtered_music.shape[1]:
    raise ValueError("The input data must have the same number of features as the fitted data.")

# Find the nearest neighbors
distance, suggestion = model.kneighbors(input_data, n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.,  4., 19., 24., 29., 30.]])

# %%
suggestion
# Out:
# array([[18, 25, 13, 17,  5, 12]])

# %%
for i in range(len(suggestion)):
    print(music.index[suggestion[i]])
# Out:
# Index(['Hector Berlioz', 'Olivier Messiaen', 'Gabriel Faure',
#        'Guillaume de Machaut', 'Camille Saint-Saens', 'Francis Poulenc'],
#       dtype='object', name='composer')

# %%
music_name = music.index

# %%
import pickle
pickle.dump(model, open('artifacts/model.pkl','wb'))
pickle.dump(music_name, open('artifacts/music_name.pkl','wb'))
pickle.dump(music, open('artifacts/music.pkl','wb'))

# %%
def recommend_song(composer_name):
    song_id = np.where(music.index == composer_name)[0][0]
    music_array = music.values
    filtered_music = music_array[:, ~np.all(np.isnan(music_array), axis=0)]

    input_data = music.iloc[song_id].values.reshape(1, -1)  # Select a single row
    if input_data.shape[1] != filtered_music.shape[1]:
        raise ValueError("The input data must have the same number of features as the fitted data.")

    # Find the nearest neighbors
    distance, suggestion = model.kneighbors(input_data, n_neighbors=6)
    for i in range(len(suggestion)):
        songs = music.index[suggestion[i]]
        for j in songs:
            print(j)

# %%
np.where(music.index == 'Francis Poulenc')[0][0]
# Out:
# 12

# %%
composer_name = 'Gabriel Faure'
recommend_song(composer_name)
# Out:
# Gabriel Faure
# Guillaume de Machaut
# Camille Saint-Saens
# Francis Poulenc
# Olivier Messiaen
# Hector Berlioz

# %%
print(pd.__version__)
# Out:
# 2.2.2
